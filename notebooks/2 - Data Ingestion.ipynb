# %% [markdown]
# # Data Ingestion
#
# Now that we have a set of PDFs, we need to ingest them into a usable, useful format. In this notebook, we'll take our folder of PDFs and ingest with OCR, along with some basic checks and visualizations.
#
# Our steps in this notebook will be:
# - Process and ingest all PDFs with tesseract for optical character recognition (OCR)
# - Perform initial basic clustering to visualize the document variation across our corpus sample
# - Do some basic quality assessments of the results of OCR ingestion
# - Explore a few specific poor quality vs high quality examples, for comparison of OCR quality at the document level
#
# <br/>
#
# *Note: With the purpose to inject more variability into our corpus, we have added a number of html files into the data_raw folder from the SEC Edgar website. We will include these documents in the steps going forward.*
#
# <br/>

# %% [markdown]
# <br/>
# <br/>
#
# ## Dependencies & Configuations
#
# First, let's load in the various required packages that we will need

# %%
import fitz
import pandas as pd
import pytesseract
from pytesseract import Output
from PIL import Image
import glob
import spacy
import os
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from typing import List, Set, Dict, Tuple
from dotenv import load_dotenv
from bs4 import BeautifulSoup

# %% [markdown]
# <br/>
#
# Set home directory - we suggest making this the data folder in the repo:

# %%
load_dotenv()
HOME_DIRECTORY = r'D:\Usersss\end-to-end-ML-Pipeline'
pytesseract.pytesseract.tesseract_cmd = r'tesseract'

# %% [markdown]
# <br/>
#
# ## Ingest and OCR documents
#
# First, we will run OCR over each PDF document using tesseract, and save the OCR results to txt files.
#
# Though it's not critical, we are going to run OCR with text position elements, which we will also save to file. Though we're not sure if we will use this information downstream, because OCR can be a proceesing bottleneck, we only want to run it once, and the text position elements are a small overhead to this process.
#
# Additionally, as noted, we're also bringing additional html files for processing from SEC Edgar to ensure we have reasonable variability in our corpus. We'll include these in the same ingestion process in this section, though OCR won't be necessary for the html files.
#
# #### First, the PDF processing:

# %%
def pdf_to_text_with_ocr(pdf_path: str, output_txt_path: str):
    '''
    Behavior:  The filename of the PDF is used to create two automatically saved output
    files - a text file and an Excel file - to the designated folder. The same name of the
    PDF is used for the names of these files. Any errors are printed to the screen.
    
    Parameters:
    - pdf_path (str): filepath to the PDF on local disk
    - output_txt_path (str): filepath to the folder in which to save
    
    Returns: None
    
    ## Example usage:
    # pdf_file_path = os.path.join(HOME_DIRECTORY, "test.pdf")
    # output_text_file_path = os.path.join(HOME_DIRECTORY, text_files)
    # pdf_to_text_with_ocr(pdf_file_path, output_text_file_path)
    '''
    try:
        # Open the PDF file using PyMuPDF
        pdf_document = fitz.open(pdf_path)
        pdf_name = os.path.basename(pdf_path)+'.txt'
        excel_name = os.path.basename(pdf_path)+'.xlsx'
    
        # Initialize an empty string to store the text content
        text_content = ""
        # Initialize an empty pandas db to store positions
        positions_df = pd.DataFrame()
    
        # Iterate through each page in the PDF
        for page_num in range(pdf_document.page_count):
            # Get the current page
            page = pdf_document[page_num]
    
            # Render the page as an image
            image = page.get_pixmap()
            img = Image.frombytes("RGB", (image.width, image.height), image.samples)
    
            # Perform OCR using pytesseract on the image
            page_text = pytesseract.image_to_string(img, lang='eng')
            positions = pytesseract.image_to_data(img, output_type=Output.DATAFRAME)
            
            # Append the extracted text to the overall content
            text_content += page_text
            positions_df = pd.concat([positions_df, positions], ignore_index=True)
    
        # Save the text content to a text file
        with open(os.path.join(output_txt_path, pdf_name), 'w', encoding='utf-8') as txt_file:
            txt_file.write(text_content)
    
        # Save positions to spreadsheet
        positions_df.to_excel(os.path.join(output_txt_path, excel_name), index=False)
    
        # Print a success message
        print(f"OCR completed successfully. Text saved at: {os.path.join(output_txt_path, pdf_name)}")

    except OSError as err:
        print("OS error:", err)
    except ValueError as err:
        print("URL or folder is invalid:", err)
    except Exception as err:
        print(f"Unexpected {err=}, {type(err)=}")
        raise

# %% [markdown]
# <br/>
#
# Now, let's pull all the names of the PDFs we want to ingest and process into a list to iterate over:

# %%
pdfs = glob.glob(os.path.join(HOME_DIRECTORY, 'data', 'data_raw', '*pdf'))
len(pdfs)
# Out:
# 2422

# %% [markdown]
# <br/>
#
# Now, let's use our function to kick off OCR processing (**note** this will take a while!) and automatically save the results.
#
# *Note:* Again, alternatively, the OCR data is available on the Google Drive to pull into your local instance.

# %%
for i, pdf in enumerate(pdfs):
    pdf_to_text_with_ocr(pdf, os.path.join(HOME_DIRECTORY, 'data', 'data_text'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 for i, pdf in enumerate(pdfs):
# ----> 2     pdf_to_text_with_ocr(pdf, os.path.join(HOME_DIRECTORY, 'data', 'data_text'))
#
# Cell In[3], line 40, in pdf_to_text_with_ocr(pdf_path, output_txt_path)
#      38 # Perform OCR using pytesseract on the image
#      39 page_text = pytesseract.image_to_string(img, lang='eng')
# ---> 40 positions = pytesseract.image_to_data(img, output_type=Output.DATAFRAME)
#      42 # Append the extracted text to the overall content
#      43 text_content += page_text
#
# File D:\Usersss\MTHM\TC2R-CodeCompanion-main\MTHM-env\Lib\site-packages\pytesseract\pytesseract.py:596, in image_to_data(image, lang, config, nice, output_type, timeout, pandas_config)
#     593 config = f'-c tessedit_create_tsv=1 {config.strip()}'
#     594 args = [image, 'tsv', lang, config, nice, timeout]
# --> 596 return {
#     597     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     598     Output.DATAFRAME: lambda: get_pandas_output(
#     599         args + [True],
#     600         pandas_config,
#     601     ),
#     602     Output.DICT: lambda: file_to_dict(run_and_get_output(*args), '\t', -1),
#     603     Output.STRING: lambda: run_and_get_output(*args),
#     604 }[output_type]()
#
# File D:\Usersss\MTHM\TC2R-CodeCompanion-main\MTHM-env\Lib\site-packages\pytesseract\pytesseract.py:598, in image_to_data.<locals>.<lambda>()
#     593 config = f'-c tessedit_create_tsv=1 {config.strip()}'
#     594 args = [image, 'tsv', lang, config, nice, timeout]
#     596 return {
#     597     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
# --> 598     Output.DATAFRAME: lambda: get_pandas_output(
#     599         args + [True],
#     600         pandas_config,
#     601     ),
#     602     Output.DICT: lambda: file_to_dict(run_and_get_output(*args), '\t', -1),
#     603     Output.STRING: lambda: run_and_get_output(*args),
#     604 }[output_type]()
#
# File D:\Usersss\MTHM\TC2R-CodeCompanion-main\MTHM-env\Lib\site-packages\pytesseract\pytesseract.py:573, in get_pandas_output(args, config)
#     570 except (TypeError, ValueError):
#     571     pass
# --> 573 return pd.read_csv(BytesIO(run_and_get_output(*args)), **kwargs)
#
# File D:\Usersss\MTHM\TC2R-CodeCompanion-main\MTHM-env\Lib\site-packages\pytesseract\pytesseract.py:352, in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     341 with save(image) as (temp_name, input_filename):
#     342     kwargs = {
#     343         'input_filename': input_filename,
#     344         'output_filename_base': temp_name,
#    (...)    349         'timeout': timeout,
#     350     }
# --> 352     run_tesseract(**kwargs)
#     353     return _read_output(
#     354         f"{kwargs['output_filename_base']}{extsep}{extension}",
#     355         return_bytes,
#     356     )
#
# File D:\Usersss\MTHM\TC2R-CodeCompanion-main\MTHM-env\Lib\site-packages\pytesseract\pytesseract.py:282, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     279     else:
#     280         raise TesseractNotFoundError()
# --> 282 with timeout_manager(proc, timeout) as error_string:
#     283     if proc.returncode:
#     284         raise TesseractError(proc.returncode, get_errors(error_string))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File D:\Usersss\MTHM\TC2R-CodeCompanion-main\MTHM-env\Lib\site-packages\pytesseract\pytesseract.py:144, in timeout_manager(proc, seconds)
#     142 try:
#     143     if not seconds:
# --> 144         yield proc.communicate()[1]
#     145         return
#     147     try:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:1205, in Popen.communicate(self, input, timeout)
#    1202     endtime = None
#    1204 try:
# -> 1205     stdout, stderr = self._communicate(input, endtime, timeout)
#    1206 except KeyboardInterrupt:
#    1207     # https://bugs.python.org/issue25942
#    1208     # See the detailed comment in .wait().
#    1209     if timeout is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\subprocess.py:1579, in Popen._communicate(self, input, endtime, orig_timeout)
#    1575 # Wait for the reader threads, or time out.  If we time out, the
#    1576 # threads remain reading and the fds left open in case the user
#    1577 # calls communicate again.
#    1578 if self.stdout is not None:
# -> 1579     self.stdout_thread.join(self._remaining_time(endtime))
#    1580     if self.stdout_thread.is_alive():
#    1581         raise TimeoutExpired(self.args, orig_timeout)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\threading.py:1112, in Thread.join(self, timeout)
#    1109     raise RuntimeError("cannot join current thread")
#    1111 if timeout is None:
# -> 1112     self._wait_for_tstate_lock()
#    1113 else:
#    1114     # the behavior of a negative timeout isn't documented, but
#    1115     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1116     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\threading.py:1132, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1129     return
#    1131 try:
# -> 1132     if lock.acquire(block, timeout):
#    1133         lock.release()
#    1134         self._stop()
#
# KeyboardInterrupt:

# %% [markdown]
# <br/><br/>
#
# #### Next, the HTML processing:
#
# As noted, we have supplemented the dataset by adding additional data from SEC Edgar into the "data_raw" folder. Below, we'll read in this data and add additional .txt files into our "data_text" folder.

# %%
def pull_text_from_html(file_list, output_dir: str):
    """
    Extracts and cleans text content from a list of HTML files.

    This function iterates through a list of file paths, attempts to open each file,
    and handles potential encoding errors by first trying 'windows-1252' and then
    'utf-8'. It then uses BeautifulSoup to parse the HTML content and extract
    all text, joining it into a single, clean string.

    Args:
        file_list (list): A list of file paths to HTML documents.

    Returns:
        list: A list of strings, where each string contains the cleaned text
              content from the corresponding HTML file.
    """
    clean_texts = []
    
    # Iterate through each file path provided in the list
    for f in file_list:
        html_string = ''  # Initialize an empty string to hold the HTML content
        
        # First, try to open the file using the 'windows-1252' encoding
        try:
            with open(f, 'r', encoding='windows-1252') as file:
                html_string = file.read()
        except Exception as e1:
            print(f'Encoding error with windows-1252 for file {f}: {e1}')
            
            # If 'windows-1252' fails, try 'utf-8' encoding
            try:
                with open(f, 'r', encoding='utf-8') as file:
                    html_string = file.read()
                    print(f'Successfully read file {f} with utf-8 encoding.')
            except Exception as e2:
                print(f'Encoding error with utf-8 for file {f}: {e2}')
                # If both encodings fail, the html_string remains empty, and the loop continues.
                
        # Use BeautifulSoup to parse the HTML and extract all text
        # .stripped_strings removes leading/trailing whitespace and empty strings
        # ' '.join() combines all the extracted strings into one single string
        if html_string:  # Only proceed if we successfully read content
            clean_text = ' '.join(BeautifulSoup(html_string, "html.parser").stripped_strings)
            clean_texts.append(clean_text)
            
            # Save the text content to a text file
            with open(os.path.join(output_dir, os.path.basename(f)) + '.txt', 'w', encoding='utf-8') as t:
                t.write(clean_text)
                print('Success', f)

        else:
            clean_texts.append(None) # Append None or an empty string if file couldn't be read
            print('Failure', f)
    return clean_texts

# %%
htmls = glob.glob(os.path.join(HOME_DIRECTORY, 'data', 'data_raw', '*.htm*')) ## get both htm and html files
len(htmls)
# Out:
# 999

# %%
texts = pull_text_from_html(htmls, os.path.join(HOME_DIRECTORY, 'data', 'data_text'))
# Out:
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\101xupamendno1toar2021l.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\20210923xex10_39.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\20240628xex10_1.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\20250504 - Consulting Agreement - Ronald Robinson.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\23 and me EX-10.1.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\4thamendmenttojpmcre.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\a102-bocchinaxworkingcapit.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\a105alphia-bccxtermloang.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\a20220214masterservicingag.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\a202302248kex101.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\a20240630ex103consultingag.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\a2z ex4-31.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\a8kelyxyb8421.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\abio-ex10_2.html
# Encoding error with windows-1252 for file D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\acrs-20230526xex10d1.htm: 'charmap' codec can't decode byte 0x9d in position 293839: character maps to <undefined>
# Successfully read file D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\acrs-20230526xex10d1.htm with utf-8 encoding.
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\acrs-20230526xex10d1.htm
# Encoding error with windows-1252 for file D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\aeon-20240318xex10d4.htm: 'charmap' codec can't decode byte 0x9d in position 2570: character maps to <undefined>
# Successfully read file D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\aeon-20240318xex10d4.htm with utf-8 encoding.
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\aeon-20240318xex10d4.htm
# Encoding error with windows-1252 for file D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\agrx-20240515xex10d1.htm: 'charmap' codec can't decode byte 0x9d in position 2354: character maps to <undefined>
# Successfully read file D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\agrx-20240515xex10d1.htm with utf-8 encoding.
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\agrx-20240515xex10d1.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\airspannet_ex10-1.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\alid_ex101.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\amendmentno5tocreditagreem.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\ampriustech-berzeliusxexcl.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\aomega12082022exh2122741.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\aort-20231231xexx1024.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\appfolioliveeasy-mergera.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\aramark ex10-1.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\arc ex101_1.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\arex-ex101_6.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\arvanaex10_1.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\ascapital_8k-ex1008.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\asep ex10-18.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\astc-ex993_6.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\astex10-20.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\atha-ex10_2.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\athena_ex9901.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\atlas ex10-3.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\avita EX-10.1.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\avns3q2024form8kex101.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\avnsform8k_12032024ex101.html
# Encoding error with windows-1252 for file D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw
htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\vivakorinc_ex10-4.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\vivakorinc_ex10-5.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\vivakor_ex1001.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\vivosex10-1.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\vkin_102.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\vkin_ex101.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\volcon_ex1003.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\vsecorporationex101-consul.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\vsecorporationex101-cwheel 2.html
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\vsecorporationex101-cwheel.html
# Encoding error with windows-1252 for file D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\vygr-20231231xex10d46.htm: 'charmap' codec can't decode byte 0x9d in position 2411: character maps to <undefined>
# Successfully read file D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\vygr-20231231xex10d46.htm with utf-8 encoding.
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\vygr-20231231xex10d46.htm
# Encoding error with windows-1252 for file D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\vygr-20240331xex10d4.htm: 'charmap' codec can't decode byte 0x9d in position 1763: character maps to <undefined>
# Successfully read file D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\vygr-20240331xex10d4.htm with utf-8 encoding.
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\vygr-20240331xex10d4.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\Wisdomex10_6.htm
# Encoding error with windows-1252 for file D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\wldn-20240228xex10d1.htm: 'charmap' codec can't decode byte 0x9d in position 1758: character maps to <undefined>
# Successfully read file D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\wldn-20240228xex10d1.htm with utf-8 encoding.
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\wldn-20240228xex10d1.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\woodvioletex10-2 2.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\woodvioletex10-2.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\xene-ex101_9.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\xlrm_ex801 2.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\xlrm_ex801.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\xlrm_ex801_2.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\xlrm_ex802.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\xlrm_ex803.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\zom_ex101 2.htm
# Success D:\Usersss\MTHM\TC2R-CodeCompanion-main\data\data_raw\zom_ex101.htm

# %% [markdown]
# <br/><br/><br/>
#
# ## Cluster and Visualize Corpus
#
# Next, let's take our OCR output and quickly visualize the results of OCR. To do that, we'll write a few functions to pull in the OCRd text from file, and run a quick term frequency inverse document frequency (TFIDF) vectorization to get a quick set of features that represent each document. Then, we'll use a K-Means clustering to cluster the documents, and a simple principal component analysis (PCA) to visualize the clusters.
#
# We're going to largely use the default settings for TFIDF vectorization and K-Means clustering and our PCA, since this is for a quick visualization of our ingested data, rather than for a deep analysis.

# %%
def read_text_files(folder_path: str):
    """
    Behavior: Read text from a folder of .txt files, ignoring other file types

    Parameters:
    - folder_path (str): Path to the folder containing .txt files.

    Returns:
    - texts (list): List of strings, where each string is the content of a text file.
    """
    texts = []
    files = []
    for filename in os.listdir(folder_path):
        if filename.lower().endswith(".txt"):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                text = file.read()
                texts.append(text)
                files.append(filename)
        # else:
        #     print('Skipping', filename, ', which is not a text file and will be excluded from analysis.')
    return texts, files
    
def perform_clustering(texts: List, X = None, num_clusters: int = 3):
    """
    Behavior: Perform unsupervised clustering on the document text.

    Parameters:
    - texts (list): List of strings, where each string is the content of a document.
    - num_clusters (int): Number of clusters for KMeans algorithm.

    Returns:
    - labels (list): List of cluster labels assigned to each document.
    """
    # Use TfidfVectorizer to convert text into numerical features
    # if X has already been fit, use provided value, else continue with fit
    if X is None:    
        vectorizer = TfidfVectorizer(stop_words='english', max_df=0.95, min_df=.05, max_features=3000, ngram_range=(1,3))
        X = vectorizer.fit_transform(texts)

    # Apply KMeans clustering
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    labels = kmeans.fit_predict(X)
    silhouette_scores = silhouette_score(X, labels)

    return labels, silhouette_scores

def find_knee(texts: List, k_values: range = range(3, 11)):    
    """
    Behavior: Perform unsupervised clustering on the document text.

    Parameters:
    - texts (list): List of strings, where each string is the content of a document.
    - k_values (range): Range of cluster values to test / examine with knee diagram.

    Returns: None
    """
    vectorizer = TfidfVectorizer(stop_words='english', max_df=0.95, min_df=.05, max_features=3000, ngram_range=(1,3))
    X = vectorizer.fit_transform(texts)

    # Calculating silhouette score for each value of k
    silhouette_scores = []
    for k in k_values:
        labels, silhouette = perform_clustering(texts, X, k)
        silhouette_scores.append(silhouette)
        
    # Plotting the knee plot
    plt.plot(k_values, silhouette_scores, marker='o')
    plt.xlabel('# of Clusters (k)')
    plt.ylabel('Silhouette Scores')
    plt.show()
    
def visualize_clusters(texts: List, labels: List):
    """
    Behavior: Visualize the clusters using principal component analysis (PCA).

    Parameters:
    - texts (list): List of strings, where each string is the content of a document.
    - labels (list): List of cluster labels assigned to each document.

    ## Example usage:
    # folder_path = HOME_DIRECTORY
    # texts = read_text_files(os.path.join(HOME_DIRECTORY, 'ocr_text/'))
    # cluster_labels = perform_clustering(texts)
    # visualize_clusters(texts, cluster_labels)
    """
    # Use TfidfVectorizer to convert text into numerical features
    vectorizer = TfidfVectorizer(stop_words='english')
    X = vectorizer.fit_transform(texts)

    # Apply PCA for dimensionality reduction
    pca = PCA(n_components=2)
    X_pca = pca.fit_transform(X.toarray())

    # Visualize clusters
    scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis', alpha=0.8)
    plt.title('Document clustering visualization (PCA)')
    plt.xlabel('Principal component 1')
    plt.ylabel('Principal component 2')
    #plt.legend(*scatter.legend_elements(), title='Clusters')
    plt.show()

# %%
folder_path = os.path.join(HOME_DIRECTORY, "data", "data_text")
texts, filenames = read_text_files(folder_path)

find_knee(texts, range(10, 23, 1))

# %% [markdown]
# <br/><br/>
#
# Now that we have our analysis functions set up, let's get a quick visualization of our documents:

# %%
cluster_labels, scores = perform_clustering(texts, num_clusters=19)
visualize_clusters(texts, cluster_labels)

# %% [markdown]
# <br/>
#
# We can see that there are a number of distinct clusters that pop out pretty obviously from our corpus. We'll dive into these in a bit more detail.

# %% [markdown]
# <br/><br/>
#
# ## OCR Quality Assessments

# %% [markdown]
# <br/>
#
# Now, let's run some basic metrics to examine quality and range of output. To do this, we'll look at the OCR'd text and check against a reference dictionary (from the spaCy package) to see how often words in the OCR'd text are words we find in a normal dictionary.
#
# While there will be some proper nouns, acronyms, or other values that we expect will show up in a document of text, if the document quality is high, we expect this to be a fairly small proportion of the text. If the OCR quality is low, we expect to see a higher rate of words with OCR errors (and thus would not show up in a normal dictionary).
#
# We will apply this analysis to both the Chicago Cook County PDFs and the SEC Edgar data. Though only the PDFs went through OCR, we can apply the below checks to both types of data.

# %%
def calculate_ocr_quality(texts: List):
    """
    Behavior: Calculate OCR quality scores for a list of texts based on recognized English words.

    Parameters:
    - texts (list): List of OCR-generated texts.

    Returns:
    - ocr_quality_scores (list): List of OCR quality scores ranging from 0 to 1
    """
    nlp = spacy.load("en_core_web_sm")
    ocr_quality_scores = []

    for text in texts:
        doc = nlp(text)
        english_word_count = sum(1 for token in doc if token.is_alpha and token.text.lower() in nlp.vocab)
        total_word_count = len(doc)

        # Calculate OCR quality as the ratio of recognized English words to total words
        quality_score = english_word_count / total_word_count if total_word_count > 0 else 0
        ocr_quality_scores.append(quality_score)

    return ocr_quality_scores

def plot_ocr_quality_histogram(ocr_quality_scores: List):
    """
    Behavior: Plot a histogram of OCR quality scores.

    Parameters:
    - ocr_quality_scores (list): List of OCR quality scores ranging from 0 to 1
    
    Returns: None
    """
    # Check if OCR quality scores are provided
    if not ocr_quality_scores:
        print("Error: No OCR quality scores provided.")
        return

    # Plot the histogram
    plt.hist(ocr_quality_scores, bins=20, range=(0, 1), edgecolor='black', alpha=0.7)
    
    # Set labels and title
    plt.title('OCR Quality Histogram')
    plt.xlabel('OCR Quality Score')
    plt.ylabel('Frequency')

    # Show the plot
    plt.show()

# %% [markdown]
# <br/>
#
# Let's now use these functions to examine our overall document quality.
#
# *Note*: this will take time to run.

# %%
ocr_quality_scores = calculate_ocr_quality(texts)
plot_ocr_quality_histogram(ocr_quality_scores)

# %% [markdown]
# <br/>
#
# ## Exercise 2.1
#
# Update the histogram to plot the OCR quality from the Cook County data and the SEC Edgar data separately. Are there differences in the distributions? If so, why may this be?

# %%
import matplotlib.pyplot as plt

sec_edgar_scores = [score for score, name in zip(ocr_quality_scores, filenames) if name.startswith('0')]
cook_county_scores = [score for score, name in zip(ocr_quality_scores, filenames) if not name.startswith('0')]

plt.figure(figsize=(10, 6))
plt.hist(sec_edgar_scores, bins=20, range=(0, 1), alpha=0.5, label='SEC Edgar', color='green', edgecolor='black')
plt.hist(cook_county_scores, bins=20, range=(0, 1), alpha=0.5, label='Cook County/Chicago', color='blue', edgecolor='black')

plt.title('OCR Quality: SEC Edgar vs. Cook County')
plt.xlabel('OCR Quality Score')
plt.ylabel('Frequency')
plt.legend()
plt.show()

print(f"SEC Edgar Docs: {len(sec_edgar_scores)}, Cook County Docs: {len(cook_county_scores)}")
# Out:
# SEC Edgar Docs: 638, Cook County Docs: 1342

# %% [markdown]
# <br/><br/>
#
# We can further look at the OCR confidence metrics from tesseract itself and do a similar analysis.
#
# *Note*: This analysis will only apply to the PDFs, and not the data from SEC Edgar.

# %%
def read_xlsx_files(folder_path: str):
    """
    Behavior: Reads text from a folder of .xlsx files

    Parameters:
    - folder_path (str): Path to the folder containing .xlsx files

    Returns:
    - xlsx_dfs (list): List of pandas dataframes, where each dataframe is the contents the OCR positions and confidence levels
    """
    xlsx_dfs = []
    files = []
    for filename in os.listdir(folder_path):
        if filename.endswith(".xlsx"):
            file_path = os.path.join(folder_path, filename)
            df = pd.read_excel(file_path, engine='openpyxl')
            files.append(filename)
            xlsx_dfs.append(df)

    return xlsx_dfs, files

def extract_ocr_conf(xlsx_dfs: List):
    """
    Behavior: Calculates an OCR confidence score from tesseract values

    Parameters:
    - xlsx_dfs (list): List of dataframes containing OCR scores

    Returns:
    - ocr_conf_scores (list): List of average OCR confidence scores, ranging from 0 to 100, for each document
    """
    ocr_conf_scores = []
    ocr_conf_scores_doc_avg = []
    
    for df in xlsx_dfs:
        for conf in df['conf'][df['conf']>0].values:
            ocr_conf_scores.append(conf)
        ocr_conf_scores_doc_avg.append(np.mean(df['conf'][df['conf']>0].values))
    return ocr_conf_scores_doc_avg

def plot_ocr_conf_histogram(ocr_conf_scores: List):
    """
    Behavior: Plots a histogram of OCR quality scores

    Parameters:
    - ocr_quality_scores (list): List of average OCR confidence scores, ranging from 0 to 100, for each document

    Returns: None
    """
    # Check if OCR quality scores are provided
    if not ocr_conf_scores:
        print("Error: No OCR quality scores provided.")
        return

    # Plot the histogram
    plt.hist(ocr_conf_scores, bins=20, range=(0, 100), edgecolor='black', alpha=0.7)
    
    # Set labels and title
    plt.title('OCR Tesseract Confidence Histogram')
    plt.xlabel('OCR Tesseract Confidence Score')
    plt.ylabel('Frequency')

    # Show the plot
    plt.show()

# %% [markdown]
# *Note* This will also take time to execute

# %%
folder_path = os.path.join(HOME_DIRECTORY, "data", "data_text")
xlsx_dfs, filenames = read_xlsx_files(folder_path)

# %%
folder_path = os.path.join(HOME_DIRECTORY, "data", "data_text")
xlsx_dfs, filenames = read_xlsx_files(folder_path)
ocr_conf_scores = extract_ocr_conf(xlsx_dfs)

plot_ocr_conf_histogram(ocr_conf_scores)

# %% [markdown]
# <br/><br/>
#
# Let's look more closely at a couple lower quality examples:

# %%
df_qual = pd.DataFrame([filenames, ocr_quality_scores, ocr_conf_scores]).T
df_qual.columns = ['Filename', 'OCR Qual', 'OCR Conf']

df_qual[df_qual['OCR Qual']<.45]
# Out:
#                Filename  OCR Qual   OCR Conf
# 2     00000BPG.pdf.xlsx  0.382353  63.967461
# 5     00000J6P.pdf.xlsx  0.430595  62.979802
# 10    00000KCW.pdf.xlsx  0.425824  67.851891
# 25    00000VC6.pdf.xlsx  0.446524  74.405337
# 53    00001R8D.pdf.xlsx  0.418288  65.560144
# 54    00001R9B.pdf.xlsx  0.441379  65.155513
# 532   000103XM.pdf.xlsx  0.419926    68.1087
# 1297                NaN       0.2        NaN

# %%
df_qual[df_qual['OCR Conf']<55].head()
# Out:
#               Filename  OCR Qual   OCR Conf
# 380  000030PX.pdf.xlsx  0.680768  54.539495
# 382  000030S5.pdf.xlsx  0.474605  54.546804
# 418  0000342C.pdf.xlsx  0.685881  53.615109
# 431  000035FN.pdf.xlsx  0.725595  51.369706
# 484  00003CDS.pdf.xlsx  0.608213  54.710095

# %%
filename = '00010J1Z.pdf.txt'
with open(os.path.join(HOME_DIRECTORY, 'data', 'data_text', filename), 'r', encoding='utf-8') as file:
    text = file.read()

text
# Out:
# %%
filename = '{3FA268E9-1763-4F99-A55F-CC66ED01491A}.pdf.txt'
with open(os.path.join(HOME_DIRECTORY, 'data', 'data_text', filename), 'r', encoding='utf-8') as file:
    text = file.read()

text
# Out:
# 'Modification Summary Report\n\nContract PO) Number: 41200\n“Modification Revision Number: 7\n\nSpecification Number: 138104\n\nName of Contractor: PAN-OCEANIC ENGINEERING CO INC\nCity Department: DEPARTMENT OF WATER MANAGEMENT.\n\nTitle of Contra\nAncillary Sewer Construction = South\n\n‘Mod Rea Number ‘Mod Reason Description\n\n303825 DOLLAR AMOUNT CHANGE PONIZODICMAA/PCMEIGIVLI\n\n$6 201,973.66\n\n‘Term of Contract: StartDate: 7/2016 nine\nEnd Date: 12/31/2019\n\nProcurement Services Contact Person: ALVIN JEFFERSON\nPlease refer tothe DPS website for Contact information under "Doing Business With The City"\n\nthas been determined, on behalf ofthe City of Chicago, with regard to this Contract Amendment!\n“Modification, thatthe circumstance suid to necessitate the change in performance were not\nreasonably foreseeable a the time the Agreement was signed, or that the change is germane to the\noriginal Agreement as signed, or thatthe change order isin the best interest ofthe City of Chicago\nAndis authorized by law.\n\nVendor Number: 1963981\n\nSabin ates, BF\n<L. COPY\n\nveonerucu YN emacs\nSoe wal man\nSEI cannes a\nSega ans sa pe 7\nchtennesnn er\nName! Par-Occanle Engineering Cormpany, ne _ row: 16 DY\n‘so Baran me\nwe an\n\n‘Proasa chock one: Estimated Amount (_)_ oF Final Amount: 4)\nPresent Encumbrence on Contact: Original Contract Award: $__ 15,038.540.00,\n\n‘Time Extonsion of ‘Current Contract Value: $__24,218,400.00\nNow End Dat Pus or (unus) $___6201,97360,\n\n‘Adjusted Contact Value: $___30,420.37368 —\n\nBecomes an Encumtance of\n‘Aopropsaton Account No: 019.0 18.0882015.2026,220640.0000.19090.181,\n\nExcept ut Hori movie oman! conoca sll ect henfbreappoved ra cargo ad nA xn ad\nfect\n\n‘nro cry a hav evans an ecepng atachad mean ns aay andres ern hr peli wae\n‘aaa ny of Cage fom any anda ln erent eo ana wera,\n\nCONTRACTOR VENOOR sinatee\n\nThe undersigned with oar 9 hs Const Metin, We fh ecu id cele change\nFaroe wor no mono} frsuotie ne eB eect wt ghd al eros epee ead\n‘Steet sgnd or tab ager the be ot fa CA OF GAICABS sn wsuhoread yan\n\nCITY OF CHICAG\n\nRas\n\nIgrunw ting “DiscLOsURe OF REYAMED PaaS?\n‘PORK WITN\'Y CALENDAR GAH OF BIT MOTINGAON\n\nDIECLOSURE OF RETAMNED PARTIES\n\nA Datta and ecesum Bosrements\n\n1s As usadnarain, Conkactor moans a pan or any whe has any canto esa wit fa Cy at\n\nSes\n\n2 aman ne on gb ane\nFs eda emg ey\n‘tall Sette a eee ts og\nte toea cans Woacic oui natie eta emen\ngiv bari, eae nga ieee ean\na net a Oe ate eta es\nSa ate\n\n» a nem orp an open sen ogee tot nt\nlig te amen Sarbanes\n‘ety nae Sones pha cyte\n\n©. Sinton\nContactor ry corse on ito:\n1. This olor in nn tne:\n‘Spectication mumbor:_|38 104\nute ot ents rset prod nde Coc Pos soul fo\nfect ce\n\n2 mannet Conacte: Pan=Ocasae. Byasis, (ots “A SINS\n\ntact seta\n‘Abech eaten pgs ¥ acess. NOTE: You ma hao torte abt\n\netd ple\nited Nene you hve aed o ssa hn, fours es\n‘Fomaton sooutmetn to cane case\n‘WAM, ‘BUSINESS ADDRESS eee ee\nwh =\n\n4 Ye Gantt undoing aid erat ioe\n4, Ta tornoson prove ew sit indacoant oe Cs aaa the nt oe\n‘er cdo wth rongect whch ts oat of Rainn Pao ean boty bene es\n\nlun” Furano i a ly dames‘ ay\n\nhe Contra is cmoatain worn dadosu fe reve and ho Foss Orta,\n\n‘Canteioe must eter ask uo Contact annsttor or hs her manage Wiser ccs S\n\n‘equim or mata ha acto,\n\nTis Disowwo of Rotainad Paro ou, 220 oa of ta Homaton prodded bs ny\n\nlactmont my be modo valle tho fete on tha ae fapeens 9 ston oe\n\nIrvoraton Act rac, o° arin. Tho Contactor wah and vanes wy pale We\nuw Gly ncoanocton wht pferohase of hen abe\n\ncms K may havo\n"ho cmploto Desconer of Rated artes fonm and en aera,\n\nada panaty of per, orf that sn wort race ls Didone of Red Pato abt\nof he Contacto ed Wat ho tomato csc ere tun on oso,\n\nLE the mo\n\nsue\nLeu. voum ater Mauger\n\nmoos we\n\neancetantvom aber me\n\nre 13 caper,\n\nray)\n\n'

# %% [markdown]
# <br/>
#
# As we visually inspect these examples - through the OCR text AND through looking at the original document - we see that though some portions of the document have higher quality, other parts do not.
#
# These particular examples appear to be PDFs of multiple separate documents that have been combined, with varying levels of quality. Some pages appear "normal", others have a significant amount of handwriting, and other pages are a level of quality that may be hard for even a human to read.
#
# <br/>

# %% [markdown]
# <br/>
#
# ### Exercise 2.2:
#
# Explore a few of the documents with very high OCR confidence scores. Does your visual inspection agree with the high OCR confidence score that was generated for these documents?
#
# <br/>

# %%
high_conf_files = df_qual.sort_values(by='OCR Conf', ascending=False).head(5)
print(high_conf_files)
# Out:
#                                             Filename  OCR Qual   OCR Conf
# 230                                00002JMP.pdf.xlsx  0.745603   86.86465
# 820  {8A1E379E-343A-4970-B9F9-4E38D5D3738A}.pdf.xlsx  0.741841  86.720714
# 307                                00002S11.pdf.xlsx  0.757956  86.423969
# 241                                00002MD3.pdf.xlsx  0.764516  86.018346
# 159                                000028X5.pdf.xlsx  0.722978  85.536868

# %%
filename = '00002JMP.pdf.txt' 

with open(os.path.join(HOME_DIRECTORY, 'data', 'data_text', filename), 'r', encoding='utf-8') as file:
    text = file.read()

print(text[:1000])
# Out:
# Modification Summary Report
#
# Contract (PO) Number: 127676
# Modification Revision Number: 13
#
# Specification Number: 885258001
#
# Name of Contractor: PERK PRODUCTS
#
# City Department: PULIC LIBRARY
#
# “Title of Contract: 18525800101 CONSUMABLE LIBRARY SUPPLIES
#
# Mod Reg Number Mod Reason Description
# MODIFICATION FOR BLANKET
# AGREEMENT NUMBER 127676
# 26737 TIME EXTENSION
# SPECIFICATION NUMBER
# BRS2SHOOIA,
#
# ‘Term of Contract: Start Date: 19/1/1999
# End Date: 12/31/2006
#
# Procurement Services Contact Person: LOREL BLAMEUSER
#
# Please refer tothe DPS website for Contact information under "Doing Business With The City".
#
# Vendor Number: 675893
# Submission Date: MAY 3 1 2008
# * DEPARTMENT OF PROCUREMENT SERVICES
#
# CONTRACT MODIFICATION
# Dept. of LIBRARY & VARIOUS Issued by: Mod. No. 26737
# Request Date: 04/24/06
# Specification No. B8S2S8001 Contract No. 127676 Series No.
# ‘Contract Description: CONSUMABLE LIBRARY SUPPLIES,
# ‘CONTRACTOR OR VENDOR
#
# Name: PERK PRODUCTS INC.
# Address: 3901 NORTH SHERIDAN ROAD
#
# iy: CHICAGO

# %% [markdown]
# <br/>
#
# ### Exercise 2.3:
#
# Further explore to assess potential patterns - are there any correlations with document length? What about with document date?
#
# How useful are these measures compared to the rate of dictionary words? Do these measurements provide different information to us?
#
# <br/>

# %%
import os
import re
import pandas as pd
import matplotlib.pyplot as plt

# 1. CLEANING: Remove junk rows and ensure Filename is a string
df_qual = df_qual.dropna(subset=['Filename']).copy()
df_qual['Filename'] = df_qual['Filename'].astype(str)

# 2. DOCUMENT LENGTH: Calculate character counts for each file
lengths = []
for fname in df_qual['Filename']:
    # Map the Excel filename in the table to the Text filename on disk
    text_filename = fname.replace('.xlsx', '.txt')
    file_path = os.path.join(HOME_DIRECTORY, 'data', 'data_text', text_filename)
    
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            lengths.append(len(f.read()))
    except (FileNotFoundError, PermissionError):
        lengths.append(0)

df_qual['Doc Length'] = lengths

# 3. DOCUMENT DATE: Extract valid years (1900-2026) to avoid "ID number noise"
def extract_clean_year(name):
    match = re.search(r'(19|20)\d{2}', str(name))
    if match:
        year = int(match.group(0))
        # Only return years that are historically relevant for your dataset
        if 1900 <= year <= 2026:
            return year
    return None

df_qual['Year'] = df_qual['Filename'].apply(extract_clean_year)

# 4. STATISTICS: Calculate Correlation Coefficients
length_corr = df_qual['Doc Length'].corr(df_qual['OCR Conf'])
# For year, we only calculate correlation where a valid year was found
valid_year_df = df_qual.dropna(subset=['Year'])
year_corr = valid_year_df['Year'].corr(valid_year_df['OCR Conf'])

print(f"--- Exercise 2.3 Results ---")
print(f"Correlation (Length vs Confidence): {length_corr:.2f}")
print(f"Correlation (Year vs Confidence): {year_corr:.2f}")
print(f"Total valid files analyzed: {len(df_qual)}")

# 5. VISUALIZATION: Create plots for the report
plt.figure(figsize=(14, 6))

# Plot A: Scatter plot of Length vs Confidence
plt.subplot(1, 2, 1)
plt.scatter(df_qual['Doc Length'], df_qual['OCR Conf'], alpha=0.4, color='royalblue')
plt.title('Relationship: Doc Length vs OCR Confidence')
plt.xlabel('Character Count')
plt.ylabel('OCR Confidence (%)')

# Plot B: Line plot of Average Quality over Time
plt.subplot(1, 2, 2)
if not valid_year_df.empty:
    valid_year_df.groupby('Year')['OCR Conf'].mean().plot(kind='line', marker='o', color='forestgreen')
    plt.title('Trend: Average OCR Confidence by Year')
    plt.xlabel('Year')
    plt.ylabel('Mean OCR Confidence')

plt.tight_layout()
plt.show()
# Out:
# --- Exercise 2.3 Results ---
# Correlation (Length vs Confidence): 0.05
# Correlation (Year vs Confidence): -0.42
# Total valid files analyzed: 981

# %% [markdown]
# <br/><br/>
#
# ## Check Cluster Assignment
#
# Here we pick a few documents from each cluster to explore each cluster's "topic" and see if there is some consistency.

# %%
clusters = pd.DataFrame([filenames, cluster_labels]).T
clusters.columns = ['Filename', 'Cluster label']
clusters.head()
# Out:
#             Filename Cluster label
# 0  000009NF.pdf.xlsx             1
# 1  00000B36.pdf.xlsx             1
# 2  00000BPG.pdf.xlsx            18
# 3  00000BQ5.pdf.xlsx             1
# 4  00000J16.pdf.xlsx             9

# %%
clusters[clusters['Cluster label']==4].head(10)
# Out:
#                                             Filename Cluster label
# 646  {03162B11-A29B-47C7-9487-4547F9868B02}.pdf.xlsx             4
# 652  {06F66D7E-E60D-43FA-A5F5-CD4440DBAC3D}.pdf.xlsx             4
# 658  {0C4A813C-9950-4D13-92F4-C17F29795120}.pdf.xlsx             4
# 662  {0E96A4F2-1CC7-4DAA-849A-F9AC7D9DB8E4}.pdf.xlsx             4
# 663  {0EFE202A-24D7-44C7-AC38-1C104B4D000C}.pdf.xlsx             4
# 666  {10B22379-0000-CE17-81B2-CDCC3404936C}.pdf.xlsx             4
# 669  {13AE2B17-8EF5-4590-BCA1-F7F2667E72E6}.pdf.xlsx             4
# 671  {14D179C7-3BB6-41F6-8152-2FC269F5356B}.pdf.xlsx             4
# 679  {17D79AB6-C914-4262-B405-1BA4864B3BF4}.pdf.xlsx             4
# 682  {1A7A843B-CBEB-4564-A1F2-9703C08715E0}.pdf.xlsx             4

# %% [markdown]
# <br/>
#
# If we open and explore some of the clusters in cluster group 4, we quickly see the pattern of contract modification documents and delegate agency grant agreement documents.

# %% [markdown]
# <br/><br/>
#
# ### Exercise 2.4:
#
# We've done some exploration for cluster 4 to examine the documents' consistency within a cluster. As an exercise, repeat for additional cluster numbers to confirm that the cluster makes sense and identify the key "topic" or document pattern in that cluster.
#
# Is there a single "category" that summarizes this cluster? Or multiple types? Does this cluster make cohesive sense (from a human perspective)?

# %%
    print(f"\n--- Cluster {i} ---")
    print(clusters[clusters['Cluster label'] == i].head(5))
# Out:
# --- Cluster 0 ---
#                                             Filename Cluster label
# 738  {49BE8A4B-89D7-4D3F-8527-A8F5918D0808}.pdf.xlsx             0
# 739  {4A88A02D-3030-4951-9FA7-99C7A92BAA52}.pdf.xlsx             0
# 740  {4AA49119-5E36-4FE9-AE87-9700034F5324}.pdf.xlsx             0
# 741  {4AFC35BF-2FE9-4950-8FF5-06D31B25AD65}.pdf.xlsx             0
# 742  {4C9F09F5-79BE-4D16-B814-BB9D012B07DB}.pdf.xlsx             0

# %% [markdown]
# <br/><br/><br/>
